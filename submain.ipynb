# %%
import pandas as pd
import cudf

df = pd.read_csv('/root/autodl-tmp/my_doc/car/car_UTF8_zh_with_header.csv')
# 把品牌为蔚来的所有燃料类型改为纯电动
df.loc[df['品牌'] == '蔚来', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '特斯拉', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '小鹏汽车', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '理想', '燃料类型'] = '增程'
df.loc[df['品牌'] == '威马汽车', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '广汽埃安', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '睿蓝汽车', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '飞凡汽车', '燃料类型'] = '纯电'
df.loc[df['品牌'] == 'ARCFOX极狐', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '凌宝汽车', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '国金汽车', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '智己汽车', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '高合汽车', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '合创汽车', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '电动屋', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '爱驰', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '百智新能源', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '欧拉', '燃料类型'] = '纯电'
df.loc[df['品牌'] == '吉利几何', '燃料类型'] = '纯电'

# df.to_csv('car_with_category_fixed0_fueltype.csv', index=False)


# 把df的日期,品牌,省份,城市,车型,车型级别,上牌量,价格区间,燃料类型列调整省份,品牌,日期,车型,城市,上牌数量,车型级别,价格区间,燃料类型
# df = df[['省份', '品牌', '日期', '车型', '城市', '上牌数量', '车型级别', '价格区间', '燃料类型']]
# df.columns = ['省份', '品牌', '日期', '车型', '城市', '上牌数量', '车型级别', '价格区间', '燃料类型']
# df.to_csv('EREV_final_result.csv', index=False)
# print(df)
# 将df去掉表头追加在car/car_UTF8_zh_with_header.csv生成新的文件
# df.to_csv('car_UTF8_zh_with_header.csv', mode='a', header=False, index=False)

# %% [markdown]
# # 重新分类

# %% [markdown]
# ## 无用

# %%
# import pandas as pd

# df = pd.read_csv('car_UTF8_zh_with_header.csv')

# # 过滤掉价格区间为0的行
# df = df[df['价格区间'] != 0]
# count_price_zero = df[df['价格区间'] == 0].shape[0]
# print(f"处理好价格区间为0的行数: {count_price_zero}")

# car_brand_categories = {
#     # 中国合资品牌（按合资公司分类）
#     '合资品牌': {
#         '上汽系': [
#             '大众',  # 上汽大众
#             '别克',  # 上汽通用
#             '雪佛兰',  # 上汽通用
#             '凯迪拉克',  # 上汽通用
#             '五菱汽车',  # 上汽通用五菱
#             '宝骏'  # 上汽通用五菱
#         ],
#         '一汽系': [
#             '大众',  # 一汽大众
#             '马自达'  # 一汽马自达
#         ],
#         '东风系': [
#             '本田',  # 东风本田
#             '标致',  # 东风标致(神龙汽车)
#             '雪铁龙',  # 东风雪铁龙(神龙汽车)
#             '日产'  # 东风日产
#         ],
#         '广汽系': [
#             '本田'  # 广汽本田
#         ],
#         '长安系': [
#             '福特',  # 长安福特
#             '马自达'  # 长安马自达
#         ],
#         '江铃系': [
#             '福特'  # 江铃福特
#         ],
#         '北汽系': [
#             '现代'  # 北京现代
#         ]
#     },
    
#     # 中国自主品牌（按企业集团分类）
#     '自主品牌': {
#         '长安系': [
#             '长安',  # 主品牌
#             '长安欧尚',  # 子品牌
#             '长安凯程',  # 子品牌
#             '长安跨越',  # 子品牌
#             '阿维塔'  # 新能源品牌
#         ],
#         '长城系': [
#             '哈弗',  # 子品牌
#             '魏牌',  # 子品牌
#             '坦克',  # 子品牌
#             '欧拉'  # 新能源品牌
#         ],
#         '吉利系': [
#             '吉利汽车',  # 主品牌
#             '吉利几何',  # 子品牌
#             '领克',  # 子品牌
#             '极氪',  # 新能源品牌
#             'Polestar极星'  # 高端品牌
#         ],
#         '比亚迪': ['比亚迪'],  # 独立品牌
#         '奇瑞系': [
#             '奇瑞',  # 主品牌
#             '星途',  # 子品牌
#             '捷途'  # 子品牌
#         ],
#         '海马': ['海马']  # 独立品牌
#     },
    
#     # 中国新势力（按企业性质分类）
#     '造车新势力': {
#         '独立新势力': [
#             '理想',  # 理想汽车
#             '蔚来',  # 蔚来汽车
#             '小鹏汽车',  # 小鹏汽车
#             '零跑汽车',  # 零跑科技
#             '哪吒汽车',  # 合众汽车
#             '威马汽车'  # 威马汽车
#         ],
#         '传统车企新品牌': [
#             'ARCFOX极狐',  # 北汽新能源
#             '广汽埃安',  # 广汽集团
#             '智己汽车',  # 上汽集团
#             '问界'  # 问界汽车
#         ],
#         '国际品牌': [
#             '特斯拉'  # 国产特斯拉
#         ]
#     },
    
#     # 中国国有品牌（按企业集团分类）
#     '国有品牌': {
#         '一汽系': [
#             '红旗',  # 高端品牌
#             '奔腾'  # 主流品牌
#         ],
#         '东风系': [
#             '东风风行',  # 子品牌
#             '东风风神',  # 子品牌
#             '东风风光',  # 子品牌
#             '东风小康',  # 子品牌
#             '启辰'  # 东风日产子品牌
#         ],
#         '上汽系': [
#             '上汽大通MAXUS',  # 商用车品牌
#             '名爵',  # 乘用车品牌
#             '荣威'  # 乘用车品牌
#         ],
#         '广汽系': [
#             '广汽传祺'  # 主品牌
#         ],
#         '北汽系': [
#             '北京',  # 子品牌
#             '北京汽车'  # 主品牌
#         ],
#         '其他国企': [
#             '金杯',  # 华晨集团
#             '东南'  # 东南汽车(福建汽车工业集团)
#         ]
#     },
    
#     # 国际品牌（按国别和定位分类）
#     '国际品牌': {
#         '德系': {
#             '豪华品牌': [
#                 '奥迪',
#                 '奔驰',
#                 '宝马'
#             ],
#             '超豪华品牌': [
#                 '保时捷',
#                 '宾利'
#             ],
#             '大众集团': [
#                 '斯柯达'
#             ],
#             'BMW集团': [
#                 'MINI'
#             ]
#         },
#         '日系': {
#             '主流品牌': [
#                 '丰田',
#                 '斯巴鲁',
#                 '三菱'
#             ],
#             '豪华品牌': [
#                 '雷克萨斯',
#                 '讴歌',
#                 '英菲尼迪'
#             ]
#         },
#         '美系': {
#             '主流品牌': [
#                 'Jeep'
#             ],
#             '豪华品牌': [
#                 '林肯'
#             ]
#         },
#         '韩系': {
#             '豪华品牌': [
#                 '捷尼赛思'
#             ],
#             '主流品牌': [
#                 '起亚'
#             ]
#         },
#         '意系': {
#             '豪华品牌': [
#                 '玛莎拉蒂'
#             ],
#             '超跑品牌': [
#                 '法拉利',
#                 '兰博基尼'
#             ]
#         },
#         '英系': {
#             '豪华品牌': [
#                 '捷豹',
#                 '路虎'
#             ],
#             '超豪华品牌': [
#                 '劳斯莱斯'
#             ]
#         },
#         '瑞典': {
#             '豪华品牌': [
#                 '沃尔沃'  # 归吉利控股
#             ]
#         }
#     }
# }

# def get_detailed_categories(brand, brand_categories):
#     for main_category, sub_dict in brand_categories.items():
#         # 处理国际品牌的特殊结构
#         if main_category == '国际品牌':
#             for nationality, sub_sub_dict in sub_dict.items():
#                 for brand_level, brands in sub_sub_dict.items():
#                     if brand in brands:
#                         return main_category, nationality, brand_level
#         # 处理其他品牌类别
#         else:
#             for sub_category, brands_list in sub_dict.items():
#                 if isinstance(brands_list, list):
#                     if brand in brands_list:
#                         return main_category, sub_category, None
#                 else:
#                     for brand_type, brands in brands_list.items():
#                         if brand in brands:
#                             return main_category, sub_category, brand_type
#     return None, None, None

# # 删除已存在的分类列
# for col in ['品牌分类', '品牌系列', '品牌细分']:
#     if col in df.columns:
#         df = df.drop(col, axis=1)

# # 应用新的分类方法
# categories_result = df['品牌'].apply(lambda x: get_detailed_categories(x, car_brand_categories))

# # 添加新的分类列
# df.insert(0, '品牌分类', categories_result.apply(lambda x: x[0]))
# df_zh_cleaned_zero.insert(1, '品牌系列', categories_result.apply(lambda x: x[1]))
# df.insert(2, '品牌细分', categories_result.apply(lambda x: x[2]))

# # 检查未匹配的品牌
# unmatched_brands = df[df['品牌分类'].isna()]['品牌'].unique()
# if len(unmatched_brands) > 0:
#     print("未匹配品牌：")
#     print(unmatched_brands)

# # 保存结果（去掉未匹配的行）
# df_matched = df.dropna(subset=['品牌分类'])

# %% [markdown]
# ### 核验未匹配品牌

# %%
# # 创建要检查的品牌列表
# brands_to_check = [
#     "飞凡汽车", "国金汽车", "高合汽车", "岚图汽车", "深蓝汽车", "天际汽车", 
#     "创维汽车", "电动屋", "凌宝汽车", "睿蓝汽车", "御捷新能源", "百智新能源",
#     "雷丁", "爱驰", "鸿蒙智行", "合创汽车", "极石汽车", "捷达", "思铭", 
#     "理念", "SWM斯威汽车", "华晨新日", "恒驰", "北汽制造", "一汽", 
#     "广汽集团", "江汽集团", "SRM鑫源", "大运汽车", "东风富康", 
#     "江铃集团新能源", "中国重汽VGV", "小虎", "东风", "瑞风汽车"
# ]

# # 检查每个品牌的最新记录
# results = []
# for brand in brands_to_check:
#     brand_data = df[df['品牌'] == brand]
#     if len(brand_data) > 0:
#         # 获取该品牌最新的日期
#         latest_date = brand_data['日期'].max()
#         # 获取该品牌的总销量
#         total_sales = brand_data['上牌数量'].sum()
#         results.append({
#             '品牌': brand,
#             '是否存在': '存在',
#             '最新记录日期': latest_date,
#             '总销量': total_sales
#         })
#     else:
#         results.append({
#             '品牌': brand,
#             '是否存在': '不存在',
#             '最新记录日期': None,
#             '总销量': 0
#         })

# # 转换为DataFrame并显示结果
# result_df = pd.DataFrame(results)
# print("品牌检查结果：")
# print(result_df)

# # 统计存在和不存在的品牌数量
# existence_stats = result_df['是否存在'].value_counts()
# print("\n统计结果：")
# print(existence_stats)

# # 获取仍在销售的品牌（可以设定一个最近日期的阈值，比如2023年后仍有记录的）
# recent_threshold = '2023-01-01'
# active_brands = result_df[
#     (result_df['是否存在'] == '存在') & 
#     (result_df['最新记录日期'] >= recent_threshold)
# ]
# print("\n2023年后仍有销售记录的品牌：")
# print(active_brands[['品牌', '最新记录日期', '总销量']])

# %% [markdown]
# 1. 原合资品牌调整：
#    - 移除了"捷达"(重复出现)
#    - 移除了"思铭"(已停产)
#    - 移除了"理念"(已停产)
#    - 移除了"SWM斯威汽车"(自主品牌)
#    - 移除了"华晨新日"(已无相关信息)
#
# 2. 原传统民企调整：
#    - "恒驰"移除(已破产)
#    - 将部分品牌按母公司归类(如吉利几何、领克均归入吉利系)
#
# 3. 原新势力调整：
#    - 移除了部分已倒闭或无实质性产品的品牌：
#      "飞凡汽车"、"国金汽车"、"高合汽车"、"岚图汽车"、
#      "深蓝汽车"、"天际汽车"、"创维汽车"、"电动屋"、
#      "凌宝汽车"、"睿蓝汽车"、"御捷新能源"、"百智新能源"、
#      "雷丁"、"爱驰"、"鸿蒙智行"、"合创汽车"、"极石汽车"
#
# 4. 原国企调整：
#    - 整合了部分重复品牌
#    - 将"思皓"、"凯翼"等品牌按母公司归类
#    - 移除了一些已停产或信息不明确的品牌：
#      "北汽制造"、"一汽"、"广汽集团"、"江汽集团"、
#      "SRM鑫源"、"大运汽车"、"东风富康"、
#      "江铃集团新能源"、"中国重汽VGV"、"小虎"、
#      "东风"、"瑞风汽车"

# %%
# print(df_matched)

# %% [markdown]
# # 完整的品牌分类

# %%
car_brand_categories_complete = {
    # 中国合资品牌
    '合资品牌': {
        '上汽系': [
            '大众',  # 上汽大众
            '别克',  # 上汽通用
            '雪佛兰',  # 上汽通用
            '凯迪拉克',  # 上汽通用
            '五菱汽车',  # 上汽通用五菱
            '宝骏'  # 上汽通用五菱
        ],
        '一汽系': [
            '大众',  # 一汽大众
            '马自达'  # 一汽马自达
        ],
        '东风系': [
            '本田',  # 东风本田
            '标致',  # 东风标致(神龙汽车)
            '雪铁龙',  # 东风雪铁龙(神龙汽车)
            '日产',  # 东风日产
            '东风富康',  # 东风合资品牌
            '捷达'  # 一汽大众子品牌
        ],
        '广汽系': [
            '本田',  # 广汽本田
            '理念'  # 广汽本田子品牌
        ],
        '长安系': [
            '福特',  # 长安福特
            '马自达'  # 长安马自达
        ],
        '江铃系': [
            '福特'  # 江铃福特
        ],
        '北汽系': [
            '现代'  # 北京现代
        ],
        '华晨系': [
            '华晨新日'  # 华晨合资品牌
        ]
    },
    
    # 中国自主品牌
    '自主品牌': {
        '长安系': [
            '长安',  # 主品牌
            '长安欧尚',  # 子品牌
            '长安凯程',  # 子品牌
            '长安跨越',  # 子品牌
            '阿维塔'  # 新能源品牌
        ],
        '长城系': [
            '哈弗',  # 子品牌
            '魏牌',  # 子品牌
            '坦克',  # 子品牌
            '欧拉'  # 新能源品牌
        ],
        '吉利系': [
            '吉利汽车',  # 主品牌
            '吉利几何',  # 子品牌
            '领克',  # 子品牌
            '极氪',  # 新能源品牌
            'Polestar极星'  # 高端品牌
        ],
        '比亚迪': ['比亚迪'],  # 独立品牌
        '奇瑞系': [
            '奇瑞',  # 主品牌
            '星途',  # 子品牌
            '捷途'  # 子品牌
        ],
        '江淮系': [
            '思皓',  # 子品牌
            '瑞风汽车'  # 子品牌
        ],
        '海马': ['海马'],  # 独立品牌
        '斯威系': [
            'SWM斯威汽车'  # 独立品牌
        ],
        '恒大系': [
            '恒驰'  # 新能源品牌
        ],
        '其他自主品牌': [
            '凯翼',  # 原奇瑞子品牌
            '思铭'  # 已停产品牌
        ]
    },
    
    # 中国造车新势力
    '造车新势力': {
        '独立新势力': [
            '理想',  # 理想汽车
            '蔚来',  # 蔚来汽车
            '小鹏汽车',  # 小鹏汽车
            '零跑汽车',  # 零跑科技
            '哪吒汽车',  # 合众汽车
            '威马汽车',  # 威马汽车
            '飞凡汽车',  # 新势力品牌
            '高合汽车',  # 新势力品牌
            '国金汽车',  # 新势力品牌
            '岚图汽车',  # 东风子品牌
            '睿蓝汽车',  # 新势力品牌
            '深蓝汽车',  # 新势力品牌
            '天际汽车',  # 新势力品牌
            '创维汽车',  # 新势力品牌
            '电动屋',  # 新势力品牌
            '凌宝汽车',  # 新势力品牌
            '御捷新能源',  # 新势力品牌
            '百智新能源',  # 新势力品牌
            '雷丁',  # 新势力品牌
            '爱驰',  # 新势力品牌
            '极石汽车'  # 新势力品牌
        ],
        '传统车企新品牌': [
            'ARCFOX极狐',  # 北汽新能源
            '广汽埃安',  # 广汽集团
            '智己汽车',  # 上汽集团
            '问界',  # 问界汽车
            '鸿蒙智行',  # 新品牌
            '合创汽车'  # 新品牌
        ],
        '国际品牌': [
            '特斯拉'  # 国产特斯拉
        ]
    },
    
    # 中国国有品牌
    '国有品牌': {
        '一汽系': [
            '一汽',  # 集团品牌
            '红旗',  # 高端品牌
            '奔腾'  # 主流品牌
        ],
        '东风系': [
            '东风',  # 集团品牌
            '东风风行',  # 子品牌
            '东风风神',  # 子品牌
            '东风风光',  # 子品牌
            '东风小康',  # 子品牌
            '启辰'  # 东风日产子品牌
        ],
        '上汽系': [
            '上汽大通MAXUS',  # 商用车品牌
            '名爵',  # 乘用车品牌
            '荣威'  # 乘用车品牌
        ],
        '广汽系': [
            '广汽集团',  # 集团品牌
            '广汽传祺'  # 主品牌
        ],
        '北汽系': [
            '北京',  # 子品牌
            '北京汽车',  # 主品牌
            '北汽制造'  # 子品牌
        ],
        '江汽系': [
            '江汽集团',  # 集团品牌
            '江铃集团新能源'  # 新能源品牌
        ],
        '商用车企业': [
            'SRM鑫源',  # 商用车品牌
            '大运汽车',  # 商用车品牌
            '中国重汽VGV',  # 商用车品牌
            '小虎'  # 商用车品牌
        ],
        '其他国企': [
            '金杯',  # 华晨集团
            '东南'  # 东南汽车(福建汽车工业集团)
        ]
    },
    
    # 国际品牌（按企业集团分类）
    '国际品牌': {
        '大众集团': [
            '大众',  # 主品牌
            '奥迪',  # 豪华品牌
            '保时捷',  # 超豪华品牌
            '宾利',  # 超豪华品牌
            '斯柯达'  # 大众子品牌
        ],
        '戴姆勒集团': [
            '奔驰'  # 主品牌
        ],
        'BMW集团': [
            '宝马',  # 主品牌
            'MINI'  # 子品牌
        ],
        '丰田集团': [
            '丰田',  # 主品牌
            '雷克萨斯'  # 豪华品牌
        ],
        '本田集团': [
            '本田',  # 主品牌
            '讴歌'  # 豪华品牌
        ],
        '日产集团': [
            '日产',  # 主品牌
            '英菲尼迪'  # 豪华品牌
        ],
        '斯巴鲁集团': [
            '斯巴鲁'  # 独立品牌
        ],
        '三菱集团': [
            '三菱'  # 独立品牌
        ],
        '福特集团': [
            '福特',  # 主品牌
            '林肯'  # 豪华品牌
        ],
        'Stellantis集团': [
            'Jeep'  # 主品牌
        ],
        '现代集团': [
            '现代',  # 主品牌
            '起亚',  # 子品牌
            '捷尼赛思'  # 豪华品牌
        ],
        '法拉利集团': [
            '法拉利',  # 主品牌
            '玛莎拉蒂'  # 豪华品牌
        ],
        '大众兰博基尼': [
            '兰博基尼'  # 超跑品牌
        ],
        '捷豹路虎集团': [
            '捷豹',  # 豪华品牌
            '路虎'  # 豪华品牌
        ],
        'BMW劳斯莱斯': [
            '劳斯莱斯'  # 超豪华品牌
        ],
        '吉利沃尔沃': [
            '沃尔沃'  # 豪华品牌
        ]
    }
}
jinkou_brand = {1: '雷克萨斯ES', 2: '雷克萨斯RX', 3: 'Cayenne', 4: '奔驰GLE', 5: 'Panamera', 6: 'Macan', 7: 'MINI', 8: '雷克萨斯NX', 9: '沃尔沃XC90', 10: '奔驰S级', 11: '奥迪A5', 12: '埃尔法', 13: '宝马4系', 14: '奔驰GLS', 15: '保时捷911', 16: '保时捷718', 17: '宝马X4', 18: '奥迪Q7', 19: '宝马X5(进口)', 20: '雷克萨斯UX', 21: 'Cayenne新能源', 22: '宝马5系(进口)', 23: 'MINI CLUBMAN', 24: 'Levante', 25: '迈巴赫S级', 26: '路虎卫士', 27: '奥迪A6(进口)', 28: 'MINI COUNTRYMAN', 29: '途锐', 30: 'Polestar 2', 31: '揽胜', 32: '奥迪A8', 33: '宝马7系', 34: '宝马X7', 35: '奥迪A4(进口)', 36: '揽胜运动版', 37: '森林人', 38: '宝马6系GT', 39: '奔驰CLA', 40: 'MINI JCW', 41: '雷克萨斯LM', 42: '宝马2系(进口)', 43: '奔驰GLE新能源', 44: '奔驰E级(进口)', 45: '奔驰GLC轿跑', 46: '雷克萨斯LS', 47: '牧马人', 48: '斯巴鲁BRZ', 49: 'Taycan', 50: '奥迪Q8', 51: '法拉利F8', 52: '奔驰GLE AMG', 53: '奔驰G级AMG', 54: '奥迪S4', 55: '奔驰CLS', 56: '宝马X6', 57: '奔驰GLC AMG', 58: '傲虎', 59: '奥迪A7', 60: '揽胜星脉', 61: '奔驰C级(进口)', 62: '奔驰A级AMG(进口)', 63: '迈巴赫GLS', 64: '奔驰G级', 65: '飞驰', 66: '添越', 67: '宝马Z4', 68: 'Urus', 69: '雷克萨斯UX新能源', 70: '大切诺基(进口)', 71: '牧马人新能源', 72: '沃尔沃V90', 73: '宝马M4', 74: '库里南', 75: '蔚揽', 76: '奔驰B级', 77: 'Giulia朱丽叶', 78: '宝马M3', 79: '奔驰CLA AMG', 80: '奔驰GLB AMG', 81: '发现', 82: '宝马8系', 83: '奔驰GLE轿跑', 84: 'Ghibli', 85: '领航员', 86: 'Panamera新能源', 87: '沃尔沃V60', 88: '沃尔沃XC90新能源', 89: '雷克萨斯GX', 90: 'AMG GT', 91: '捷豹F-PACE', 92: '宝马i4', 93: '捷尼赛思G80', 94: '捷尼赛思GV80', 95: 'Mustang', 96: '雷克萨斯LX', 97: '宝马i3(进口)', 98: '奔驰GLA AMG', 99: '帕里斯帝', 100: '奥迪SQ5', 101: 'MINI JCW CLUBMAN', 102: '途乐', 103: 'Mirai', 104: '奔驰EQS', 105: 'Huracan', 106: '奥迪S5', 107: '奥迪RS 5', 108: '阿斯顿·马丁DBX', 109: '雷克萨斯LC', 110: '丰田86', 111: '捷尼赛思G70', 112: '宝马iX', 113: 'Bronco(进口)', 114: '捷尼赛思纯电G80', 115: '奥迪e-tron(进口)', 116: '马自达MX-5', 117: '兰德酷路泽(进口)', 118: '普拉多(进口)', 119: '吉姆尼(进口)', 120: '宝马X3(进口)', 121: '宝马X5 M', 122: '捷尼赛思GV70', 123: '宝马i7', 124: '宝马X3 M', 125: '红杉', 126: '雷克萨斯RZ', 127: '路特斯ELETRE', 128: '奔驰GLE轿跑新能源', 129: '雷克萨斯NX新能源', 130: 'Grecale格雷嘉', 131: '宝马X4 M', 132: 'Sienna', 133: 'Portofino', 134: '奔驰V级(进口)', 135: '宝马XM', 136: '古思特', 137: '宝马M2', 138: '雷克萨斯RX新能源', 139: '捷豹F-TYPE', 140: '思域(进口)', 141: 'Supra', 142: 'Roma', 143: '斯巴鲁CROSSTREK 旭豹', 144: '法拉利296', 145: '奔驰S级新能源', 146: 'EMIRA', 147: '奔驰EQS AMG', 148: 'FJ 酷路泽', 149: '奔驰EQS SUV', 150: '奔驰EQE AMG', 151: 'Polestar 4', 152: '奥迪RS 4', 153: '皇冠(进口)', 154: '赛那SIENNA', 155: '宝马X2(进口)', 156: '奔驰A级(进口)', 157: '奔驰CLE', 158: '迈迈', 159: '帕杰罗(进口)', 160: '奥迪RS e-tron GT'}
zizhu_brand = {1: '汉', 2: '元PLUS', 3: '宋PLUS新能源', 4: 'AION Y', 5: 'AION S', 6: '宏光MINIEV', 7: '红旗E-QM5', 8: '秦PLUS', 9: '奔腾NAT', 10: '荣威Ei5', 11: '极氪001', 12: '小鹏P7', 13: '理想ONE', 14: '长安CS75 PLUS', 15: '北京EU5', 16: '小鹏P5', 17: '蔚来ET7', 18: '吉利几何A', 19: '秦新能源', 20: 'QQ
 257: '揽巡', 258: '狮铂拓界', 259: '广汽丰田bZ4X', 260: '一汽丰田bZ4X', 261: '英菲尼迪QX60', 262: '菲斯塔', 263: '北斗星X5', 264: '指南者', 265: 'mu-X牧游侠', 266: '自由光', 267: '格瑞维亚', 268: '宝沃BXi7', 269: '宝马i3', 270: '奥迪Q5L Sportback', 271: '奇骏·荣耀', 272: '奥迪A6', 273: '世纪', 274: '奕歌', 275: '丰田bZ3', 276: '别克E5', 277: '标致408X', 278: 'DS 9', 279: '凯迪拉克GT4', 280: '本田HR-V', 281: '马自达CX-50行也', 282: 'Model X', 283: '赛图斯', 284: 'Model S', 285: 'smart精灵#3', 286: 'MUFASA 沐飒', 287: '奔驰EQE SUV', 288: '雅阁新能源', 289: '别克E4', 290: '日产帕拉丁', 291: '捷豹E-PACE', 292: '宝马iX1', 293: '昂科拉PLUS', 294: '路特斯ELETRE', 295: '起亚EV5', 296: '大众ID.7 VIZZION', 297: '伊兰特Elantra N', 298: '宝马i5', 299: '探陆', 300: '路特斯EMEYA繁花', 301: '沃尔沃EM90', 302: 'IQ傲歌', 303: '福特烈马', 304: '沃尔沃EX30', 305: '别克GL8新能源', 306: 'e:NP2 极湃2', 307: 'DS 7', 308: '电动MINI COOPER', 309: 'L380', 310: '探界者Plus', 311: 'ID.UNYX 与众', 312: '马自达EZ-6', 313: '普拉多', 314: '猎光e:NS2', 315: '电动MINI ACEMAN', 316: '高尔夫GTI', 317: 'smart精灵#5'}

def get_detailed_categories(brand, brand_categories):
    for main_category, sub_dict in brand_categories.items():
        # 处理所有品牌类别
        for sub_category, brands_list in sub_dict.items():
            if isinstance(brands_list, list):
                if brand in brands_list:
                    return main_category, sub_category
    return None, None

# 根据进口品牌字典判断并更新厂商类型
def check_import(model):
    for import_model in jinkou_brand.values():
        if import_model == model:
            return '进口'
    for import_model in zizhu_brand.values():
        if import_model == model:
            return '自主'
    for import_model in hezi_brand.values():
        if import_model == model:
            return '合资'
    return 'NA'

# 删除已存在的分类列
for col in ['品牌分类', '品牌系列','品牌细分','厂商类型']:
    if col in df.columns:
        df = df.drop(col, axis=1)

# 应用新的分类方法
categories_result = df['品牌'].apply(lambda x: get_detailed_categories(x, car_brand_categories_complete))
# df['厂商类型'] = 'NA'

# 应用判断函数到车型列
df['厂商类型'] = df['车型'].apply(check_import)

# 添加新的分类列
df.insert(0, '品牌分类', categories_result.apply(lambda x: x[0]))
df.insert(1, '品牌系列', categories_result.apply(lambda x: x[1]))
# 应用判断函数到车型列
df['厂商类型'] = df['车型'].apply(check_import)
# 将厂商类型列移到品牌分类和品牌系列之后
df = df[['厂商类型', '品牌分类', '品牌系列', '省份', '品牌', '日期', '车型', '城市', '上牌数量', '车型级别', '价格区间', '燃料类型']]
df.columns = ['厂商类型', '品牌分类', '品牌系列', '省份', '品牌', '日期', '车型', '城市', '上牌数量', '车型级别', '价格区间', '燃料类型']
# cols = df.columns.tolist()
# cols.remove('厂商类型')
# cols.insert(0, '厂商类型')  # 插入到第1列的位置
# df = df[cols]

# 检查未匹配的品牌
unmatched_brands = df[df['品牌分类'].isna()]['品牌'].unique()
if len(unmatched_brands) > 0:
    print("未匹配品牌：")
    print(unmatched_brands)
else:
    print("所有品牌均已成功匹配。")

# 保存结果（去掉未匹配的行）
df_matched = df.dropna(subset=['品牌分类'])

# 显示分类结果统计
print("\n品牌分类统计：")
print(df_matched['品牌分类'].value_counts())
print("\n品牌系列统计：")
print(df_matched['品牌系列'].value_counts())
# 显示结果统计
print("\n厂商类型统计：")
print(df_matched['厂商类型'].value_counts())
print(df_matched.head(10))
# Out:
# 所有品牌均已成功匹配。
#
# 品牌分类统计：
# 品牌分类
# 合资品牌     862273
# 自主品牌     654039
# 国际品牌     642012
# 国有品牌     220010
# 造车新势力    145384
# Name: count, dtype: int64
#
# 品牌系列统计：
# 品牌系列
# 上汽系             532573
# 东风系             343315
# 丰田集团            260988
# 长安系             190518
# 吉利系             161028
# 比亚迪             138406
# 戴姆勒集团           103320
# 大众集团            102648
# 独立新势力           102168
# 奇瑞系              93860
# 长城系              92988
# BMW集团            91644
# 一汽系              65436
# 北汽系              47635
# 广汽系              46116
# 传统车企新品牌          37420
# 吉利沃尔沃            25200
# 捷豹路虎集团           18816
# 福特集团             15540
# 现代集团             12264
# 江淮系              10332
# 国际品牌              5796
# 三菱集团              4452
# 商用车企业             3612
# 江汽系               3612
# 其他国企              3360
# 其他自主品牌            2940
# Stellantis集团      2604
# 斯巴鲁集团             2436
# 法拉利集团              756
# 日产集团               588
# 本田集团               420
# BMW劳斯莱斯            252
# ...

# %%
print(df_matched)
# Out:
#         厂商类型   品牌分类   品牌系列   省份    品牌        日期          车型    城市  上牌数量  车型级别  \
# 0         合资   合资品牌    上汽系   北京    大众  2022年06月  ID.4 CROZZ    北京   847   SUV
# 1         合资   合资品牌    上汽系   北京    大众  2022年06月          迈腾    北京   854   中型车
# 2         合资   合资品牌    上汽系   北京    大众  2022年06月          探岳    北京   483   SUV
# 3         合资   合资品牌    上汽系   北京    大众  2022年06月          宝来    北京   436  紧凑型车
# 4         合资   合资品牌    上汽系   北京    大众  2022年06月         途观L    北京   552   SUV
# ...      ...    ...    ...  ...   ...       ...         ...   ...   ...   ...
# 2523713   自主  造车新势力  独立新势力  内蒙古  哪吒汽车  2024年10月         哪吒L  呼和浩特    11   SUV
# 2523714   自主   自主品牌    奇瑞系   山西    星途  2024年10月      星纪元 ET    太原    11   SUV
# 2523715   自主  造车新势力  独立新势力   河北  岚图汽车  2024年10月      岚图FREE    沧州    11   SUV
# 2523716   自主  造车新势力  独立新势力   河北  深蓝汽车  2024年10月      深蓝SL03    保定    11   中型车
# 2523717   自主  造车新势力  独立新势力   北京  哪吒汽车  2024年10月       哪吒S猎装    北京    11  中大型车
#
#                 价格区间 燃料类型
# ...

# %%
df_matched.to_csv('car_with_category.csv', index=False)
